# %% [markdown]
# # 1 Installing the YOLOv8 Environment
#
# To start off with YOLOv8 we first clone the YOLOv8 repository and install dependencies. This will set up our programming environment to be ready to running object detection training and inference commands.

# %%
# Clone repository
# !git clone https://github.com/ultralytics/ultralytics

# Navigate to the cloned directory
# %cd ultralytics

# Install the package in editable mode for development
# !pip install -e .
# Out:
# C:\Users\CP1\Documents\GitHub\Itemized-Billing\ultralytics
# fatal: destination path 'ultralytics' already exists and is not an empty directory.
# Obtaining file:///C:/Users/CP1/Documents/GitHub/Itemized-Billing/ultralytics
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: matplotlib>=3.2.2 in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from ultralytics==8.0.171) (3.7.3)
# Requirement already satisfied: numpy>=1.22.2 in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from ultralytics==8.0.171) (1.25.2)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from ultralytics==8.0.171) (4.8.0.76)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from ultralytics==8.0.171) (10.0.1)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from ultralytics==8.0.171) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from ultralytics==8.0.171) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from ultralytics==8.0.171) (1.11.3)
# Requirement already satisfied: torch>=1.8.0 in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from ultralytics==8.0.171) (1.13.1+cu116)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from ultralytics==8.0.171) (0.14.1+cu116)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from ultralytics==8.0.171) (4.66.1)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from ultralytics==8.0.171) (2.1.1)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from ultralytics==8.0.171) (0.13.0)
# Requirement already satisfied: psutil in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from ultralytics==8.0.171) (5.9.5)
# Requirement already satisfied: py-cpuinfo in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from ultralytics==8.0.171) (9.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from matplotlib>=3.2.2->ultralytics==8.0.171) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from matplotlib>=3.2.2->ultralytics==8.0.171) (0.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from matplotlib>=3.2.2->ultralytics==8.0.171) (4.43.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from matplotlib>=3.2.2->ultralytics==8.0.171) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from matplotlib>=3.2.2->ultralytics==8.0.171) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from matplotlib>=3.2.2->ultralytics==8.0.171) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from matplotlib>=3.2.2->ultralytics==8.0.171) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from pandas>=1.1.4->ultralytics==8.0.171) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from pandas>=1.1.4->ultralytics==8.0.171) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from requests>=2.23.0->ultralytics==8.0.171) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from requests>=2.23.0->ultralytics==8.0.171) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from requests>=2.23.0->ultralytics==8.0.171) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from requests>=2.23.0->ultralytics==8.0.171) (2023.7.22)
# Requirement already satisfied: typing-extensions in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from torch>=1.8.0->ultralytics==8.0.171) (4.8.0)
# Requirement already satisfied: colorama in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from tqdm>=4.64.0->ultralytics==8.0.171) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.2.2->ultralytics==8.0.171) (1.16.0)
# Installing collected packages: ultralytics
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.0.165
# WARNING: Error parsing requirements for ultralytics: [Errno 2] No such file or directory: 'c:\\users\\cp1\\documents\\github\\itemized-billing\\venv\\lib\\site-packages\\ultralytics-8.0.165.dist-info\\METADATA'
#     WARNING: No metadata found in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages
# ERROR: Cannot uninstall ultralytics 8.0.165, RECORD file not found. You might be able to recover from this via: 'pip install --force-reinstall --no-deps ultralytics==8.0.165'.

# %% [markdown]
# # 2 Import Libraries

# %%
import torch
print('torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
from ultralytics import YOLO

import yaml
import glob
from IPython.display import Image, display
from IPython.core.magic import register_line_cell_magic

from DataAugmentation import DataAugmentation
# Out:
# torch 1.13.1+cu116 _CudaDeviceProperties(name='NVIDIA GeForce RTX 3090', major=8, minor=6, total_memory=24575MB, multi_processor_count=82)

# %%
# %cd ..

# Open and read the YAML file
with open('configuration/config-HB.yaml', 'r') as file:
    yaml_data = yaml.safe_load(file)

yaml_data
# Out:
# C:\Users\CP1\Documents\GitHub\Itemized-Billing
# {'path': 'C:/Users/CP1/Documents/GitHub/Itemized-Billing/HB-yolo-1.1',
#  'train': 'train.txt',
#  'val': 'valid.txt',
#  'nc': 1,
#  'names': ['table']}

# %%
# Define number of classes based on YAML
with open('configuration/config-HB.yaml', 'r') as stream:
    num_classes = str(yaml.safe_load(stream)['nc'])

print(f'Number of class: {num_classes}')
# Out:
# Number of class: 1

# %%
import os

current_directory = os.getcwd()
print("Current Directory:", current_directory)
# Out:
# Current Directory: C:\Users\CP1\Documents\GitHub\Itemized-Billing

# %% [markdown]
# # 3 Train YOLOv8

# %%
model = YOLO('yolov8s.pt')  # build a new model from scratch

results = model.train(data='configuration/config-HB.yaml', epochs=50, workers=2, imgsz=416)  # train the model
# Out:
# New https://pypi.org/project/ultralytics/8.0.194 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.171  Python-3.10.10 torch-1.13.1+cu116 CUDA:0 (NVIDIA GeForce RTX 3090, 24576MiB)
# WARNING  Upgrade to torch>=2.0.0 for deterministic training.
# engine\trainer: task=detect, mode=train, model=yolov8s.pt, data=configuration/config-HB.yaml, epochs=50, patience=50, batch=16, imgsz=416, save=True, save_period=-1, cache=False, device=None, workers=2, project=None, name=None, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, stream_buffer=False, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=runs\detect\train45
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2116435  ultralytics.nn.modules.head.Detect           [1, [128, 256, 512]]
# Model summary: 225 layers, 11135987 parameters, 11135971 gradients, 28.6 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed
# train: Scanning HB-yolo-1.1\obj_train_data... 360 images, 0 backgrounds, 0 corrupt: 100%|██████████| 360/360 [00:00<00:00, 727.55it/s]
# train: New cache created: HB-yolo-1.1\obj_train_data.cache
# val: Scanning HB-yolo-1.1\obj_train_data... 40 images, 0 backgrounds, 0 corrupt: 100%|██████████| 40/40 [00:00<00:00, 649.87it/s]
# val: New cache created: HB-yolo-1.1\obj_train_data.cache
# Plotting labels to runs\detect\train45\labels.jpg...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 416 train, 416 val
# Using 2 dataloader workers
# Logging results to runs\detect\train45
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      1.78G      1.583      2.606      1.613         17        416: 100%|██████████| 23/23 [00:16<00:00,  1.36it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  8.59it/s]
#                    all         40         40      0.452       0.75       0.46      0.286
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      1.87G      0.849      1.099      1.044         16        416: 100%|██████████| 23/23 [00:14<00:00,  1.56it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  9.58it/s]
#                    all         40         40      0.601       0.85      0.713      0.313
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      1.87G      0.837     0.8561      1.029         18        416: 100%|██████████| 23/23 [00:14<00:00,  1.61it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  8.73it/s]
#                    all         40         40      0.535       0.95      0.729      0.329
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      1.87G     0.7464     0.7436     0.9967         15        416: 100%|██████████| 23/23 [00:14<00:00,  1.61it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  7.91it/s]
#                    all         40         40      0.449        0.6       0.42      0.102
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      1.87G     0.7323     0.6655     0.9843         20        416: 100%|██████████| 23/23 [00:13<00:00,  1.64it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  9.29it/s]
#                    all         40         40      0.413      0.686      0.604      0.257
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      1.87G      0.736     0.7221     0.9987         17        416: 100%|██████████| 23/23 [00:14<00:00,  1.58it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00, 10.49it/s]
#                    all         40         40      0.926      0.575      0.772      0.584
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      1.87G     0.6971     0.6437     0.9716         18        416: 100%|██████████| 23/23 [00:14<00:00,  1.56it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  9.27it/s]
#                    all         40         40      0.354      0.475      0.299      0.175
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      1.87G     0.6538     0.5816     0.9674         21        416: 100%|██████████| 23/23 [00:14<00:00,  1.59it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  6.30it/s]
#                    all         40         40      0.874       0.75      0.872      0.776
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      1.87G     0.5658     0.5021      0.938         19        416: 100%|██████████| 23/23 [00:13<00:00,  1.73it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  8.46it/s]
#                    all         40         40      0.633      0.904      0.868      0.722
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      1.87G     0.5779     0.4979     0.9393         23        416: 100%|██████████| 23/23 [00:14<00:00,  1.62it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  8.94it/s]
#                    all         40         40          1      0.997      0.995      0.929
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      1.87G     0.5609     0.5139     0.9413         19        416: 100%|██████████| 23/23 [00:15<00:00,  1.53it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  7.92it/s]
#                    all         40         40      0.924          1      0.987      0.865
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      1.86G     0.5276     0.4738      0.921         14        416: 100%|██████████| 23/23 [00:15<00:00,  1.53it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  9.92it/s]
#                    all         40         40      0.982          1      0.995      0.902
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      1.86G     0.4942     0.4464     0.9028         20        416: 100%|██████████| 23/23 [00:17<00:00,  1.35it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  9.54it/s]
#                    all         40         40      0.995      0.975      0.995      0.861
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      1.87G     0.5142     0.4538     0.9175         21        416: 100%|██████████| 23/23 [00:15<00:00,  1.49it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00, 10.00it/s]
#                    all         40         40      0.975          1      0.995      0.915
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      1.87G     0.4794     0.4116     0.8989         23        416: 100%|██████████| 23/23 [00:14<00:00,  1.57it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  9.19it/s]
#                    all         40         40      0.997          1      0.995      0.953
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      1.87G     0.4376     0.4003     0.9004         23        416: 100%|██████████| 23/23 [00:14<00:00,  1.58it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  8.25it/s]
#                    all         40         40      0.998          1      0.995       0.96
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      1.87G     0.4272     0.3736     0.8826         23        416: 100%|██████████| 23/23 [00:14<00:00,  1.53it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  9.95it/s]
#                    all         40         40      0.999          1      0.995      0.948
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50      1.87G     0.4312     0.3657      0.885         23        416: 100%|██████████| 23/23 [00:15<00:00,  1.47it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  9.68it/s]
#                    all         40         40      0.999          1      0.995      0.962
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50      1.87G     0.4459     0.3921     0.8846         18        416: 100%|██████████| 23/23 [00:15<00:00,  1.52it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  9.48it/s]
#                    all         40         40      0.998          1      0.995      0.954
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      1.86G     0.3964     0.3558     0.8802         19        416: 100%|██████████| 23/23 [00:14<00:00,  1.61it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  8.42it/s]
#                    all         40         40      0.998          1      0.995      0.971
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50      1.87G     0.3795      0.338     0.8864         21        416: 100%|██████████| 23/23 [00:15<00:00,  1.53it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  8.18it/s]
#                    all         40         40      0.997          1      0.995       0.96
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50      1.87G     0.4044     0.3475     0.8988         20        416: 100%|██████████| 23/23 [00:15<00:00,  1.53it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  9.34it/s]
#                    all         40         40      0.998          1      0.995      0.959
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50      1.87G     0.3886     0.3361     0.8796         22        416: 100%|██████████| 23/23 [00:14<00:00,  1.55it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  9.01it/s]
#                    all         40         40      0.999          1      0.995      0.977
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50      1.86G     0.3754     0.3332      0.884         15        416: 100%|██████████| 23/23 [00:14<00:00,  1.59it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00, 10.31it/s]
#                    all         40         40      0.999          1      0.995      0.973
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50      1.87G     0.3649     0.3188     0.8809         20        416: 100%|██████████| 23/23 [00:14<00:00,  1.59it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  9.03it/s]
#                    all         40         40      0.998          1      0.995      0.924
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50      1.87G     0.3735     0.3164     0.8749         19        416: 100%|██████████| 23/23 [00:14<00:00,  1.54it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  9.31it/s]
#                    all         40         40      0.998          1      0.995      0.973
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      1.87G     0.3547     0.3111     0.8703         17        416: 100%|██████████| 23/23 [00:15<00:00,  1.51it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  8.47it/s]
#                    all         40         40      0.999          1      0.995      0.963
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50      1.86G     0.3394     0.2937     0.8726         18        416: 100%|██████████| 23/23 [00:14<00:00,  1.54it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  9.17it/s]
#                    all         40         40      0.999          1      0.995      0.978
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50      1.87G     0.3526     0.3039     0.8701         21        416: 100%|██████████| 23/23 [00:14<00:00,  1.57it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  8.38it/s]
#                    all         40         40      0.995          1      0.995      0.965
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      1.87G     0.3474     0.2903     0.8648         20        416: 100%|██████████| 23/23 [00:14<00:00,  1.58it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  9.34it/s]
#                    all         40         40      0.999          1      0.995      0.979
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50      1.87G     0.3348      0.293      0.874         22        416: 100%|██████████| 23/23 [00:14<00:00,  1.55it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  8.01it/s]
#                    all         40         40      0.998          1      0.995      0.973
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50      1.87G     0.3277     0.2817     0.8653         17        416: 100%|██████████| 23/23 [00:14<00:00,  1.55it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  8.62it/s]
#                    all         40         40      0.998          1      0.995      0.971
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50      1.87G     0.3171     0.2771     0.8622         17        416: 100%|██████████| 23/23 [00:16<00:00,  1.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  8.79it/s]
#                    all         40         40      0.999          1      0.995      0.975
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50      1.87G     0.3199     0.2824      0.866         23        416: 100%|██████████| 23/23 [00:15<00:00,  1.50it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  9.30it/s]
#                    all         40         40      0.999          1      0.995      0.975
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50      1.87G     0.3258     0.2947     0.8689         18        416: 100%|██████████| 23/23 [00:15<00:00,  1.51it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  9.39it/s]
#                    all         40         40      0.999          1      0.995      0.975
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50      1.87G     0.3222     0.2908     0.8673         19        416: 100%|██████████| 23/23 [00:15<00:00,  1.45it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00, 10.47it/s]
#                    all         40         40      0.999          1      0.995      0.977
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      1.87G      0.308     0.2644     0.8618         19        416: 100%|██████████| 23/23 [00:14<00:00,  1.63it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  8.33it/s]
#                    all         40         40      0.998          1      0.995      0.981
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      1.87G     0.3132     0.2747     0.8697         17        416: 100%|██████████| 23/23 [00:14<00:00,  1.62it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  9.69it/s]
#                    all         40         40      0.999          1      0.995      0.984
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      1.87G     0.2882     0.2541     0.8668         15        416: 100%|██████████| 23/23 [00:14<00:00,  1.59it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  8.95it/s]
#                    all         40         40      0.999          1      0.995      0.986
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      1.86G     0.2884     0.2591     0.8647         19        416: 100%|██████████| 23/23 [00:14<00:00,  1.58it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  8.79it/s]
#                    all         40         40      0.999          1      0.995      0.984
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      1.86G     0.2591     0.2173     0.8079          8        416: 100%|██████████| 23/23 [00:18<00:00,  1.22it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  9.86it/s]
#                    all         40         40      0.999          1      0.995      0.982
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      1.87G     0.2661     0.2111     0.7917          8        416: 100%|██████████| 23/23 [00:15<00:00,  1.47it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  9.21it/s]
#                    all         40         40      0.999          1      0.995      0.977
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      1.87G      0.263     0.2231     0.8105          8        416: 100%|██████████| 23/23 [00:15<00:00,  1.48it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  9.61it/s]
#                    all         40         40      0.999          1      0.995      0.982
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      1.87G     0.2516     0.2067     0.8189          8        416: 100%|██████████| 23/23 [00:15<00:00,  1.48it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  9.77it/s]
#                    all         40         40      0.999          1      0.995      0.976
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      1.86G     0.2531     0.2003     0.7997          8        416: 100%|██████████| 23/23 [00:14<00:00,  1.54it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  8.64it/s]
#                    all         40         40      0.999          1      0.995      0.975
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      1.86G     0.2403     0.1914     0.7975          8        416: 100%|██████████| 23/23 [00:14<00:00,  1.56it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  9.66it/s]
#                    all         40         40      0.999          1      0.995       0.98
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      1.86G     0.2315     0.1888     0.7969          8        416: 100%|██████████| 23/23 [00:14<00:00,  1.55it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00, 10.00it/s]
#                    all         40         40      0.999          1      0.995      0.986
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      1.87G     0.2232     0.1795     0.7984          8        416: 100%|██████████| 23/23 [00:15<00:00,  1.50it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00, 10.27it/s]
#                    all         40         40      0.998          1      0.995      0.985
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      1.86G      0.213     0.1739     0.7933          8        416: 100%|██████████| 23/23 [00:15<00:00,  1.52it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  9.14it/s]
#                    all         40         40      0.999          1      0.995      0.981
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      1.86G     0.2122      0.169     0.8008          8        416: 100%|██████████| 23/23 [00:14<00:00,  1.60it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00, 10.26it/s]
#                    all         40         40      0.999          1      0.995      0.986
#
# 50 epochs completed in 0.223 hours.
# Optimizer stripped from runs\detect\train45\weights\last.pt, 22.5MB
# Optimizer stripped from runs\detect\train45\weights\best.pt, 22.5MB
#
# Validating runs\detect\train45\weights\best.pt...
# Ultralytics YOLOv8.0.171  Python-3.10.10 torch-1.13.1+cu116 CUDA:0 (NVIDIA GeForce RTX 3090, 24576MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00, 10.47it/s]
#                    all         40         40      0.999          1      0.995      0.986
# Speed: 0.1ms preprocess, 1.8ms inference, 0.0ms loss, 0.8ms postprocess per image

# %% [markdown]
# # 4 Evaluate the model

# %%
results.results_dict
# Out:
# {'metrics/precision(B)': 0.9986141406653237,
#  'metrics/recall(B)': 1.0,
#  'metrics/mAP50(B)': 0.995,
#  'metrics/mAP50-95(B)': 0.9859482625482627,
#  'fitness': 0.9868534362934365}

# %%
# We can also output some older school graphs if the tensor board isn't working for whatever reason...
Image(filename=f'{str(results.save_dir)}/results.png', width=1000)

# %% [markdown]
# ## 4.1 Visualize the Training Data

# %%
Image(filename=f'{str(results.save_dir)}/train_batch0.jpg', width=900)

# %% [markdown]
# ## 4.2 Visualize the Labels of Validating Data

# %%
Image(filename=f'{str(results.save_dir)}/val_batch0_labels.jpg', width=900)

# %% [markdown]
# ## 4.3 Visualize the Predicted Testing Data

# %%
Image(filename=f'{str(results.save_dir)}/val_batch0_pred.jpg', width=900)

# %% [markdown]
# # 5 Run Inference  With Trained Weights
# Run inference with a pretrained checkpoint on contents of `test/images` folder downloaded from Roboflow.

# %%
source = 'CVAT/Testing Set'
model = YOLO(f'{str(results.save_dir)}/weights/best.pt')
# model = YOLO('best.pt')

deskewer = DataAugmentation(source)
deskewer.processor()

prediction = model.predict(source=source, save=True, imgsz=416)
# Out:
# 1. CVAT/Testing Set\TEST_BAGAN_001.png
# 2. CVAT/Testing Set\TEST_BAGAN_002.png
# 3. CVAT/Testing Set\TEST_BAGAN_003.png
# 4. CVAT/Testing Set\TEST_BAGAN_004.png
# 5. CVAT/Testing Set\TEST_BAGAN_005.png
# 6. CVAT/Testing Set\TEST_BAGAN_006.png
# 7. CVAT/Testing Set\TEST_BAGAN_007.png
# 8. CVAT/Testing Set\TEST_BAGAN_008.png
# 9. CVAT/Testing Set\TEST_BAGAN_009.png
# 10. CVAT/Testing Set\TEST_BAGAN_010.png
# 11. CVAT/Testing Set\TEST_GNC_001.png
# 12. CVAT/Testing Set\TEST_GNC_002.png
# 13. CVAT/Testing Set\TEST_GNC_003.png
# 14. CVAT/Testing Set\TEST_GNC_004.png
# 15. CVAT/Testing Set\TEST_GNC_005.png
# 16. CVAT/Testing Set\TEST_GNC_006.png
# 17. CVAT/Testing Set\TEST_GNC_007.png
# 18. CVAT/Testing Set\TEST_GNC_008.png
# 19. CVAT/Testing Set\TEST_GNC_009.png
# 20. CVAT/Testing Set\TEST_GNC_010.png
# 21. CVAT/Testing Set\TEST_KPJ_001.png
# 22. CVAT/Testing Set\TEST_KPJ_002.png
# 23. CVAT/Testing Set\TEST_KPJ_003.png
# 24. CVAT/Testing Set\TEST_KPJ_004.png
# 25. CVAT/Testing Set\TEST_KPJ_005.png
# 26. CVAT/Testing Set\TEST_KPJ_006.png
# 27. CVAT/Testing Set\TEST_KPJ_007.png
# 28. CVAT/Testing Set\TEST_KPJ_008.png
# 29. CVAT/Testing Set\TEST_KPJ_009.png
# 30. CVAT/Testing Set\TEST_KPJ_010.png
# 31. CVAT/Testing Set\TEST_RSH_001.png
# 32. CVAT/Testing Set\TEST_RSH_002.png
# 33. CVAT/Testing Set\TEST_RSH_003.png
# 34. CVAT/Testing Set\TEST_RSH_004.png
# 35. CVAT/Testing Set\TEST_RSH_005.png
# 36. CVAT/Testing Set\TEST_RSH_006.png
# 37. CVAT/Testing Set\TEST_RSH_007.png
# 38. CVAT/Testing Set\TEST_RSH_008.png
# 39. CVAT/Testing Set\TEST_RSH_009.png
# 40. CVAT/Testing Set\TEST_RSH_010.png
# image 1/40 C:\Users\CP1\Documents\GitHub\Itemized-Billing\CVAT\Testing Set\TEST_BAGAN_001.png: 416x320 1 table, 29.0ms
# image 2/40 C:\Users\CP1\Documents\GitHub\Itemized-Billing\CVAT\Testing Set\TEST_BAGAN_002.png: 416x320 1 table, 26.6ms
# image 3/40 C:\Users\CP1\Documents\GitHub\Itemized-Billing\CVAT\Testing Set\TEST_BAGAN_003.png: 416x320 1 table, 29.0ms
# image 4/40 C:\Users\CP1\Documents\GitHub\Itemized-Billing\CVAT\Testing Set\TEST_BAGAN_004.png: 416x320 1 table, 28.0ms
# image 5/40 C:\Users\CP1\Documents\GitHub\Itemized-Billing\CVAT\Testing Set\TEST_BAGAN_005.png: 416x320 1 table, 32.0ms
# image 6/40 C:\Users\CP1\Documents\GitHub\Itemized-Billing\CVAT\Testing Set\TEST_BAGAN_006.png: 416x320 1 table, 27.0ms
# image 7/40 C:\Users\CP1\Documents\GitHub\Itemized-Billing\CVAT\Testing Set\TEST_BAGAN_007.png: 416x320 1 table, 28.0ms
# image 8/40 C:\Users\CP1\Documents\GitHub\Itemized-Billing\CVAT\Testing Set\TEST_BAGAN_008.png: 416x320 1 table, 28.0ms
# image 9/40 C:\Users\CP1\Documents\GitHub\Itemized-Billing\CVAT\Testing Set\TEST_BAGAN_009.png: 416x320 1 table, 26.0ms
# image 10/40 C:\Users\CP1\Documents\GitHub\Itemized-Billing\CVAT\Testing Set\TEST_BAGAN_010.png: 416x320 1 table, 28.5ms
# image 11/40 C:\Users\CP1\Documents\GitHub\Itemized-Billing\CVAT\Testing Set\TEST_GNC_001.png: 416x320 1 table, 29.0ms
# image 12/40 C:\Users\CP1\Documents\GitHub\Itemized-Billing\CVAT\Testing Set\TEST_GNC_002.png: 416x320 1 table, 26.6ms
# image 13/40 C:\Users\CP1\Documents\GitHub\Itemized-Billing\CVAT\Testing Set\TEST_GNC_003.png: 416x320 1 table, 26.0ms
# image 14/40 C:\Users\CP1\Documents\GitHub\Itemized-Billing\CVAT\Testing Set\TEST_GNC_004.png: 416x320 1 table, 31.2ms
# image 15/40 C:\Users\CP1\Documents\GitHub\Itemized-Billing\CVAT\Testing Set\TEST_GNC_005.png: 416x320 1 table, 26.0ms
# image 16/40 C:\Users\CP1\Documents\GitHub\Itemized-Billing\CVAT\Testing Set\TEST_GNC_006.png: 416x320 1 table, 34.0ms
# image 17/40 C:\Users\CP1\Documents\GitHub\Itemized-Billing\CVAT\Testing Set\TEST_GNC_007.png: 416x320 1 table, 26.0ms
# image 18/40 C:\Users\CP1\Documents\GitHub\Itemized-Billing\CVAT\Testing Set\TEST_GNC_008.png: 416x320 1 table, 25.4ms
# image 19/40 C:\Users\CP1\Documents\GitHub\Itemized-Billing\CVAT\Testing Set\TEST_GNC_009.png: 416x320 1 table, 28.0ms
# image 20/40 C:\Users\CP1\Documents\GitHub\Itemized-Billing\CVAT\Testing Set\TEST_GNC_010.png: 416x320 1 table, 27.0ms
# image 21/40 C:\Users\CP1\Documents\GitHub\Itemized-Billing\CVAT\Testing Set\TEST_KPJ_001.png: 416x320 1 table, 27.0ms
# image 22/40 C:\Users\CP1\Documents\GitHub\Itemized-Billing\CVAT\Testing Set\TEST_KPJ_002.png: 416x320 1 table, 26.6ms
# image 23/40 C:\Users\CP1\Documents\GitHub\Itemized-Billing\CVAT\Testing Set\TEST_KPJ_003.png: 416x320 1 table, 32.0ms
# image 24/40 C:\Users\CP1\Documents\GitHub\Itemized-Billing\CVAT\Testing Set\TEST_KPJ_004.png: 416x320 1 table, 27.0ms
# image 25/40 C:\Users\CP1\Documents\GitHub\Itemized-Billing\CVAT\Testing Set\TEST_KPJ_005.png: 416x320 1 table, 26.0ms
# image 26/40 C:\Users\CP1\Documents\GitHub\Itemized-Billing\CVAT\Testing Set\TEST_KPJ_006.png: 416x320 1 table, 28.5ms
# image 27/40 C:\Users\CP1\Documents\GitHub\Itemized-Billing\CVAT\Testing Set\TEST_KPJ_007.png: 416x320 1 table, 27.0ms
# image 28/40 C:\Users\CP1\Documents\GitHub\Itemized-Billing\CVAT\Testing Set\TEST_KPJ_008.png: 416x320 1 table, 25.5ms
# image 29/40 C:\Users\CP1\Documents\GitHub\Itemized-Billing\CVAT\Testing Set\TEST_KPJ_009.png: 416x320 1 table, 28.0ms
# image 30/40 C:\Users\CP1\Documents\GitHub\Itemized-Billing\CVAT\Testing Set\TEST_KPJ_010.png: 416x320 1 table, 25.3ms
# image 31/40 C:\Users\CP1\Documents\GitHub\Itemized-Billing\CVAT\Testing Set\TEST_RSH_001.png: 416x320 1 table, 36.0ms
# image 32/40 C:\Users\CP1\Documents\GitHub\Itemized-Billing\CVAT\Testing Set\TEST_RSH_002.png: 416x320 1 table, 26.0ms
# image 33/40 C:\Users\CP1\Documents\GitHub\Itemized-Billing\CVAT\Testing Set\TEST_RSH_003.png: 416x320 1 table, 28.0ms
# image 34/40 C:\Users\CP1\Documents\GitHub\Itemized-Billing\CVAT\Testing Set\TEST_RSH_004.png: 416x320 1 table, 27.6ms
# image 35/40 C:\Users\CP1\Documents\GitHub\Itemized-Billing\CVAT\Testing Set\TEST_RSH_005.png: 416x320 1 table, 26.0ms
# image 36/40 C:\Users\CP1\Documents\GitHub\Itemized-Billing\CVAT\Testing Set\TEST_RSH_006.png: 416x320 1 table, 27.0ms
# image 37/40 C:\Users\CP1\Documents\GitHub\Itemized-Billing\CVAT\Testing Set\TEST_RSH_007.png: 416x320 1 table, 27.0ms
# image 38/40 C:\Users\CP1\Documents\GitHub\Itemized-Billing\CVAT\Testing Set\TEST_RSH_008.png: 416x320 1 table, 27.0ms
# image 39/40 C:\Users\CP1\Documents\GitHub\Itemized-Billing\CVAT\Testing Set\TEST_RSH_009.png: 416x320 1 table, 25.5ms
# image 40/40 C:\Users\CP1\Documents\GitHub\Itemized-Billing\CVAT\Testing Set\TEST_RSH_010.png: 416x320 1 table, 27.0ms
# Speed: 2.2ms preprocess, 27.8ms inference, 2.1ms postprocess per image at shape (1, 3, 416, 320)
# Results saved to runs\detect\predict63
