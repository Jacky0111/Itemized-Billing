# %% [markdown]
# # 1 Installing the YOLOv8 Environment
#
# To start off with YOLOv8 we first clone the YOLOv8 repository and install dependencies. This will set up our programming environment to be ready to running object detection training and inference commands.

# %%
# Clone repository
# !git clone https://github.com/ultralytics/ultralytics

# Navigate to the cloned directory
# %cd ultralytics

# Install the package in editable mode for development
# !pip install -e .
# Out:
# C:\Users\CP1\Documents\GitHub\Itemized-Billing\ultralytics
# fatal: destination path 'ultralytics' already exists and is not an empty directory.
# Obtaining file:///C:/Users/CP1/Documents/GitHub/Itemized-Billing/ultralytics
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: matplotlib>=3.2.2 in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from ultralytics==8.0.171) (3.7.3)
# Requirement already satisfied: numpy>=1.22.2 in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from ultralytics==8.0.171) (1.25.2)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from ultralytics==8.0.171) (4.8.0.76)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from ultralytics==8.0.171) (10.0.1)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from ultralytics==8.0.171) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from ultralytics==8.0.171) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from ultralytics==8.0.171) (1.11.3)
# Requirement already satisfied: torch>=1.8.0 in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from ultralytics==8.0.171) (1.13.1+cu116)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from ultralytics==8.0.171) (0.14.1+cu116)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from ultralytics==8.0.171) (4.66.1)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from ultralytics==8.0.171) (2.1.1)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from ultralytics==8.0.171) (0.13.0)
# Requirement already satisfied: psutil in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from ultralytics==8.0.171) (5.9.5)
# Requirement already satisfied: py-cpuinfo in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from ultralytics==8.0.171) (9.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from matplotlib>=3.2.2->ultralytics==8.0.171) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from matplotlib>=3.2.2->ultralytics==8.0.171) (0.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from matplotlib>=3.2.2->ultralytics==8.0.171) (4.43.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from matplotlib>=3.2.2->ultralytics==8.0.171) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from matplotlib>=3.2.2->ultralytics==8.0.171) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from matplotlib>=3.2.2->ultralytics==8.0.171) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from matplotlib>=3.2.2->ultralytics==8.0.171) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from pandas>=1.1.4->ultralytics==8.0.171) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from pandas>=1.1.4->ultralytics==8.0.171) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from requests>=2.23.0->ultralytics==8.0.171) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from requests>=2.23.0->ultralytics==8.0.171) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from requests>=2.23.0->ultralytics==8.0.171) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from requests>=2.23.0->ultralytics==8.0.171) (2023.7.22)
# Requirement already satisfied: typing-extensions in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from torch>=1.8.0->ultralytics==8.0.171) (4.8.0)
# Requirement already satisfied: colorama in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from tqdm>=4.64.0->ultralytics==8.0.171) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.2.2->ultralytics==8.0.171) (1.16.0)
# Installing collected packages: ultralytics
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.0.165
# WARNING: Error parsing requirements for ultralytics: [Errno 2] No such file or directory: 'c:\\users\\cp1\\documents\\github\\itemized-billing\\venv\\lib\\site-packages\\ultralytics-8.0.165.dist-info\\METADATA'
#     WARNING: No metadata found in c:\users\cp1\documents\github\itemized-billing\venv\lib\site-packages
# ERROR: Cannot uninstall ultralytics 8.0.165, RECORD file not found. You might be able to recover from this via: 'pip install --force-reinstall --no-deps ultralytics==8.0.165'.

# %% [markdown]
# # 2 Import Libraries

# %%
import torch
print('torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
from ultralytics import YOLO

import yaml
import glob
from IPython.display import Image, display
from IPython.core.magic import register_line_cell_magic

from DataAugmentation import DataAugmentation
# Out:
# torch 1.13.1+cu116 _CudaDeviceProperties(name='NVIDIA GeForce RTX 3090', major=8, minor=6, total_memory=24575MB, multi_processor_count=82)

# %%
# %cd ..

# Open and read the YAML file
with open('configuration/config-HB.yaml', 'r') as file:
    yaml_data = yaml.safe_load(file)

yaml_data
# Out:
# C:\Users\CP1\Documents\GitHub\Itemized-Billing
# {'path': 'C:/Users/CP1/Documents/GitHub/Itemized-Billing/HB-yolo-1.1',
#  'train': 'train.txt',
#  'val': 'valid.txt',
#  'nc': 1,
#  'names': ['table']}

# %%
# Define number of classes based on YAML
with open('configuration/config-HB.yaml', 'r') as stream:
    num_classes = str(yaml.safe_load(stream)['nc'])

print(f'Number of class: {num_classes}')
# Out:
# Number of class: 1

# %%
import os

current_directory = os.getcwd()
print("Current Directory:", current_directory)
# Out:
# Current Directory: C:\Users\CP1\Documents\GitHub\Itemized-Billing

# %% [markdown]
# # 3 Train YOLOv8

# %%
model = YOLO('yolov8s.pt')  # build a new model from scratch

results = model.train(data='configuration/config-HB.yaml', epochs=50, workers=2, imgsz=416)  # train the model
# Out:
# New https://pypi.org/project/ultralytics/8.0.193 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.171  Python-3.10.10 torch-1.13.1+cu116 CUDA:0 (NVIDIA GeForce RTX 3090, 24576MiB)
# WARNING  Upgrade to torch>=2.0.0 for deterministic training.
# engine\trainer: task=detect, mode=train, model=yolov8s.pt, data=configuration/config-HB.yaml, epochs=50, patience=50, batch=16, imgsz=416, save=True, save_period=-1, cache=False, device=None, workers=2, project=None, name=None, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, stream_buffer=False, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=runs\detect\train43
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2116435  ultralytics.nn.modules.head.Detect           [1, [128, 256, 512]]
# Model summary: 225 layers, 11135987 parameters, 11135971 gradients, 28.6 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed
# train: Scanning HB-yolo-1.1\obj_train_data... 360 images, 90 backgrounds, 0 corrupt: 100%|██████████| 360/360 [00:00<00:00, 603.32it/s]
# train: New cache created: HB-yolo-1.1\obj_train_data.cache
# val: Scanning HB-yolo-1.1\obj_train_data... 40 images, 20 backgrounds, 0 corrupt: 100%|██████████| 40/40 [00:00<00:00, 540.11it/s]
# val: New cache created: HB-yolo-1.1\obj_train_data.cache
# Plotting labels to runs\detect\train43\labels.jpg...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 416 train, 416 val
# Using 2 dataloader workers
# Logging results to runs\detect\train43
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      1.77G      1.632      3.029      1.699         14        416: 100%|██████████| 23/23 [00:16<00:00,  1.36it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  6
00:00,  1.45it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00, 12.80it/s]
#                    all         40         20      0.665          1      0.663      0.624
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50      1.86G     0.3864     0.3619     0.8776         11        416: 100%|██████████| 23/23 [00:15<00:00,  1.52it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00, 11.54it/s]
#                    all         40         20      0.666          1      0.663      0.605
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50      1.86G     0.3581     0.3506     0.8837         14        416: 100%|██████████| 23/23 [00:15<00:00,  1.46it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00, 12.63it/s]
#                    all         40         20      0.666          1      0.663       0.62
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      1.86G     0.3505     0.3306     0.8787         12        416: 100%|██████████| 23/23 [00:16<00:00,  1.39it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00, 11.47it/s]
#                    all         40         20      0.665          1      0.663      0.629
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50      1.86G     0.3466     0.3234     0.8821         13        416: 100%|██████████| 23/23 [00:16<00:00,  1.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00, 12.17it/s]
#                    all         40         20      0.665          1      0.663      0.632
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50      1.86G     0.3427     0.3231     0.8766         13        416: 100%|██████████| 23/23 [00:15<00:00,  1.47it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00, 10.20it/s]
#                    all         40         20      0.665          1      0.722      0.694
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      1.86G      0.334     0.3163     0.8646         15        416: 100%|██████████| 23/23 [00:14<00:00,  1.55it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00, 11.63it/s]
#                    all         40         20      0.665          1      0.678      0.652
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50      1.86G      0.335     0.3092     0.8842         16        416: 100%|██████████| 23/23 [00:15<00:00,  1.47it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00, 10.52it/s]
#                    all         40         20      0.665          1      0.689      0.651
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50      1.86G     0.3181        0.3      0.867         14        416: 100%|██████████| 23/23 [00:15<00:00,  1.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00, 11.99it/s]
#                    all         40         20      0.666          1      0.727      0.699
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50      1.86G     0.3027     0.2872     0.8657         11        416: 100%|██████████| 23/23 [00:16<00:00,  1.37it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00, 11.08it/s]
#                    all         40         20      0.665          1      0.761      0.727
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50      1.86G     0.3201     0.2969     0.8652         20        416: 100%|██████████| 23/23 [00:16<00:00,  1.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00, 12.80it/s]
#                    all         40         20      0.666          1      0.736        0.7
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50      1.86G     0.3039     0.3047     0.8709         12        416: 100%|██████████| 23/23 [00:15<00:00,  1.52it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00, 12.10it/s]
#                    all         40         20      0.665          1      0.663      0.632
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50      1.86G     0.3207     0.3022     0.8799         16        416: 100%|██████████| 23/23 [00:15<00:00,  1.53it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  9.73it/s]
#                    all         40         20      0.665          1      0.695       0.66
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      1.86G     0.2999     0.2825     0.8661         15        416: 100%|██████████| 23/23 [00:13<00:00,  1.72it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00, 11.53it/s]
#                    all         40         20      0.665          1      0.678      0.652
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      1.86G     0.3028     0.2774     0.8715         12        416: 100%|██████████| 23/23 [00:14<00:00,  1.58it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00, 12.36it/s]
#                    all         40         20      0.666          1      0.678      0.648
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      1.86G     0.2882     0.2777     0.8736         12        416: 100%|██████████| 23/23 [00:14<00:00,  1.60it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00, 10.53it/s]
#                    all         40         20      0.665          1      0.678       0.65
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      1.86G     0.2359     0.2793     0.8704         19        416:  13%|█▎        | 3/23 [00:00<00:05,  3.36it/s]

# %% [markdown]
# # 4 Evaluate the model

# %%
results.results_dict

# %%
# We can also output some older school graphs if the tensor board isn't working for whatever reason...
Image(filename=f'{str(results.save_dir)}/results.png', width=1000)

# %% [markdown]
# ## 4.1 Visualize the Training Data

# %%
Image(filename=f'{str(results.save_dir)}/train_batch0.jpg', width=900)

# %% [markdown]
# ## 4.2 Visualize the Labels of Validating Data

# %%
Image(filename=f'{str(results.save_dir)}/val_batch0_labels.jpg', width=900)

# %% [markdown]
# ## 4.3 Visualize the Predicted Testing Data

# %%
Image(filename=f'{str(results.save_dir)}/val_batch0_pred.jpg', width=900)

# %% [markdown]
# # 5 Run Inference  With Trained Weights
# Run inference with a pretrained checkpoint on contents of `test/images` folder downloaded from Roboflow.

# %%
source = 'CVAT/Testing Set'
model = YOLO(f'{str(results.save_dir)}/weights/best.pt')
# model = YOLO('best.pt')

deskewer = DataAugmentation(source)
deskewer.processor()

prediction = model.predict(source=source, save=True, imgsz=416)
